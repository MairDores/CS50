# %% [markdown]
# <a href="https://colab.research.google.com/github/MairDores/CS50/blob/master/NewBegginnings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input('What\'s your name?\n')
age = int(input('And your age?\n'))
year = int(2026) - age + 100
print(name + ' you will turn 100 yo in the year: ' + str(year))
# Out:
# What's your name?
# Mair
# And your age?
# 34
# Mair you will turn 100 yo in the year: 2092

# %% [markdown]
# Odd or Even # New Section

# %%
num = input('Give me an integer number: ')

try:
  num = int(num)
  if number % 2 == 0:
    print('Your number is even.')
  else:
    print('Your number is odd.')

except ValueError:
    print('You didn\'t enter a valid number.')

print('Congradulations on the working program!')
# Out:
# Give me an integer number: ana
# You didn't enter a valid number.
# Congradulations on the working program!
